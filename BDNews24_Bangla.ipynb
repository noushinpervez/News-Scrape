# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def extract_article_content(url, div_class_name, skip_class_name):
    try:
        with requests.get(url) as response:
            response.raise_for_status()
            html_content = response.text

        soup = BeautifulSoup(html_content, 'html.parser')
        skip_elements = soup.find_all('div', class_=skip_class_name)

        for skip_element in skip_elements:
            skip_element.decompose()

        div_elements = soup.find_all('div', class_=div_class_name)
        div_texts = [re.sub(r'\s+', ' ', div.get_text(separator=' ').strip()) for div in div_elements]
        return ' '.join(div_texts)

    except requests.exceptions.RequestException as e:
        return f"Error fetching HTML content: {e}"

# %%
def scrape_articles(offset, limit, div_class_name, skip_class_name):
    data_list = []
    article_number = 1

    while article_number <= 2000:
        url = f"https://bangla.bdnews24.com/api/v1/collections/105128?item-type=story&offset={offset}&limit={limit}"

        try:
            with requests.get(url) as response:
                response.raise_for_status()
                data = response.json()
            items = data.get('items', [])

            if not items:
                print("No more items. Breaking the loop.")
                break

            for item in items:
                story = item.get('story', {})
                headline, subheadline, slug = story.get('headline', ''), story.get('subheadline', ''), story.get('slug', '')

                if headline and slug:
                    article_url = f"https://bangla.bdnews24.com/{slug}"
                    div_content = extract_article_content(article_url, div_class_name, skip_class_name)

                    data_list.append({
                        'URL': article_url,
                        'Headline': headline,
                        'Summary': subheadline,
                        'Article': div_content
                    })

                    print(f"Article {article_number}: Successfully scraped content for: {article_url}")
                    article_number += 1

                    if article_number > 2000:
                        print("Reached the limit of 20000 articles. Stopping.")
                        break

            offset += limit

        except (requests.exceptions.RequestException, json.JSONDecodeError) as e:
            print(f"Error fetching or decoding data: {e}")
            break

    return data_list

# %%
dataset = scrape_articles(0, 10, 'story-element-text', 'story-element-text-also-read')
df = pd.DataFrame(dataset)
df.to_csv('/content/drive/MyDrive/bdnews24_financial_news_dataset.csv', index=False, encoding='utf-8')
# Out:
# Article 1: Successfully scraped content for: https://bangla.bdnews24.com/business/uhk88mxm1q
# Article 2: Successfully scraped content for: https://bangla.bdnews24.com/business/3yyibpn00s
# Article 3: Successfully scraped content for: https://bangla.bdnews24.com/business/eaxq7med9p
# Article 4: Successfully scraped content for: https://bangla.bdnews24.com/business/u02ataizh8
# Article 5: Successfully scraped content for: https://bangla.bdnews24.com/business/p439wot1vn
# Article 6: Successfully scraped content for: https://bangla.bdnews24.com/business/llo8w95nf1
# Article 7: Successfully scraped content for: https://bangla.bdnews24.com/business/pums2rvhqt
# Article 8: Successfully scraped content for: https://bangla.bdnews24.com/business/69pt7bfix2
# Article 9: Successfully scraped content for: https://bangla.bdnews24.com/business/kpfy2m6dvo
# Article 10: Successfully scraped content for: https://bangla.bdnews24.com/business/glhjuluzvl
# Article 11: Successfully scraped content for: https://bangla.bdnews24.com/bangladesh/wkt2ziixoe
# Article 12: Successfully scraped content for: https://bangla.bdnews24.com/business/8r6axfpbnv
# Article 13: Successfully scraped content for: https://bangla.bdnews24.com/business/qkijpmyx99
# Article 14: Successfully scraped content for: https://bangla.bdnews24.com/ctg/8zyta6bd5g
# Article 15: Successfully scraped content for: https://bangla.bdnews24.com/business/x1lquw2qlk
# Article 16: Successfully scraped content for: https://bangla.bdnews24.com/bangladesh/9xg783h77f
# Article 17: Successfully scraped content for: https://bangla.bdnews24.com/bangladesh/aa1etnnu2j
# Article 18: Successfully scraped content for: https://bangla.bdnews24.com/business/tmefjfb10l
# Article 19: Successfully scraped content for: https://bangla.bdnews24.com/business/87ukdfrq6z
# Article 20: Successfully scraped content for: https://bangla.bdnews24.com/business/g5pjpys1hy
# Article 21: Successfully scraped content for: https://bangla.bdnews24.com/business/vhwsvoy93l
# Article 22: Successfully scraped content for: https://bangla.bdnews24.com/business/nhd64kw6ir
# Article 23: Successfully scraped content for: https://bangla.bdnews24.com/business/7rn9l9wdcv
# Article 24: Successfully scraped content for: https://bangla.bdnews24.com/business/mjmkua87gc
# Article 25: Successfully scraped content for: https://bangla.bdnews24.com/business/vpddju6n1w
# Article 26: Successfully scraped content for: https://bangla.bdnews24.com/business/uw98v43c8g
# Article 27: Successfully scraped content for: https://bangla.bdnews24.com/business/jms4qe04pb
# Article 28: Successfully scraped content for: https://bangla.bdnews24.com/business/nnxw61uv4u
# Article 29: Successfully scraped content for: https://bangla.bdnews24.com/business/7chbb0mt3w
# Article 30: Successfully scraped content for: https://bangla.bdnews24.com/stocks/66m0td21np
# Article 31: Successfully scraped content for: https://bangla.bdnews24.com/business/shza9zk3pr
# Article 32: Successfully scraped content for: https://bangla.bdnews24.com/business/sx8ah32fuv
# Article 33: Successfully scraped content for: https://bangla.bdnews24.com/business/oza5itjuml
# Article 34: Successfully scraped content for: https://bangla.bdnews24.com/business/d639tz3nbq
# Article 35: Successfully scraped content for: https://bangla.bdnews24.com/business/f2fo6ol91g
# Article 36: Successfully scraped content for: https://bangla.bdnews24.com/campus/vx43f3r8de
# Article 37: Successfully scraped content for: https://bangla.bdnews24.com/campus/eic1by5her
# Article 38: Successfully scraped content for: https://bangla.bdnews24.com/business/6hp059lkt7
# Article 39: Successfully scraped content for: https://bangla.bdnews24.com/business/1xcd1y7v6h
# Article 40: Successfully scraped content for: https://bangla.bdnews24.com/business/47f4uhnivd
# Article 41: Successfully scraped content for: https://bangla.bdnews24.com/business/aaj0bnbj51
# Article 42: Successfully scraped content for: https://bangla.bdnews24.com/business/5ek50c51vr
# Article 43: Successfully scraped content for: https://bangla.bdnews24.com/business/6cy5lfmnha
# Article 44: Successfully scraped content for: https://bangla.bdnews24.com/business/tnl97z57fd
# Article 45: Successfully scraped content for: https://bangla.bdnews24.com/economy/z93y1zzbbt
# Article 46: Successfully scraped content for: https://bangla.bdnews24.com/business/j4ndfr7pz1
# Article 47: Successfully scraped content for: https://bangla.bdnews24.com/business/1ji4ryphh9
# Article 48: Successfully scraped content for: https://bangla.bdnews24.com/business/att6zccnzm
# Article 49: Successfully scraped content for: https://bangla.bdnews24.com/business/eh2r32km1m
# Article 50: Successfully scraped content for: https://bangla.bdnews24.com/business/xyov2rlxzn
# Article 51: Successfully scraped content for: https://bangla.bdnews24.com/business/gufv4wzzyb
# Article 52: Successfully scraped content for: https://bangla.bdnews24.com/business/shd2f0o4ay
# Article 53: Successfully scraped content for: https://bangla.bdnews24.com/business/nrwtjldivy
# Article 54: Successfully scraped content for: https://bangla.bdnews24.com/business/xnrkkitktg
# Article 55: Successfully scraped content for: https://bangla.bdnews24.com/business/jwxd7489gn
# Article 56: Successfully scraped content for: https://bangla.bdnews24.com/business/kslc88s4px
# Article 57: Successfully scraped content for: https://bangla.bdnews24.com/samagrabangladesh/3gzbyslagq
# Article 58: Successfully scraped content for: https://bangla.bdnews24.com/business/0hz0486hkr
# Article 59: Successfully scraped content for: https://bangla.bdnews24.com/business/pcgpwr1532
# Article 60: Successfully scraped content for: https://bangla.bdnews24.com/business/1l3ydf0s4r
# Article 61: Successfully scraped content for: https://bangla.bdnews24.com/business/6qed02e4y6
# Article 62: Successfully scraped content for: https://bangla.bdnews24.com/samagrabangladesh/l22ps2532q
# Article 63: Successfully scraped content for: https://bangla.bdnews24.com/business/51ezjejr9m
# Article 64: Successfully scraped content for: https://bangla.bdnews24.com/business/f2zta22se0
# Article 65: Successfully scraped content for: https://bangla.bdnews24.com/business/t2rpyp3rgr
# Article 66: Successfully scraped content for: https://bangla.bdnews24.com/business/51l2ovziv8
# Article 67: Successfully scraped content for: https://bangla.bdnews24.com/business/xvp6uq1c9d
# Article 68: Successfully scraped content for: https://bangla.bdnews24.com/business/ajcnnem49d
# Article 69: Successfully scraped content for: https://bangla.bdnews24.com/business/7wkxyfxyc5
# Article 70: Successfully scraped content for: https://bangla.bdnews24.com/business/44pegxb10l
# Article 71: Successfully scraped content for: https://bangla.bdnews24.com/business/diebypk5q0
# Article 72: Successfully scraped content for: https://bangla.bdnews24.com/business/ips8mkbzaa
# Article 73: Successfully scraped content for: https://bangla.bdnews24.com/business/bm4lkqsdyk
# Article 74: Successfully scraped content for: https://bangla.bdnews24.com/business/jop1zodnbk
# Article 75: Successfully scraped content for: https://bangla.bdnews24.com/business/kzq8f6jlnk
# Article 76: Successfully scraped content for: https://bangla.bdnews24.com/business/qr84zw062g
# Article 77: Successfully scraped content for: https://bangla.bdnews24.com/business/6gjop7gstu
# Article 78: Successfully scraped content for: https://bangla.bdnews24.com/business/crfa1i30p4
# Article 79: Successfully scraped content for: https://bangla.bdnews24.com/business/7pkny68psu
# Article 80: Successfully scraped content for: https://bangla.bdnews24.com/business/ohhtnslse2
# Article 81: Successfully scraped content for: https://bangla.bdnews24.com/business/87vnzsa0yh
# Article 82: Successfully scraped content for: https://bangla.bdnews24.com/business/i9khaf5upc
# Article 83: Successfully scraped content for: https://bangla.bdnews24.com/business/zbdmt5r7e2
# Article 84: Successfully scraped content for: https://bangla.bdnews24.com/business/qjnqzhes7p
# Article 85: Successfully scraped content for: https://bangla.bdnews24.com/business/6tcin33113
# Article 86: Successfully scraped content for: https://bangla.bdnews24.com/business/gfbxrhm97n
# Article 87: Successfully scraped content for: https://bangla.bdnews24.com/business/onyary5sqs
# Article 88: Successfully scraped content for: https://bangla.bdnews24.com/business/i7su1r655h
# Article 89: Successfully scraped content for: https://bangla.bdnews24.com/business/412s4yuk0o
# Article 90: Successfully scraped content for: https://bangla.bdnews24.com/business/emuermcncm
# Article 91: Successfully scraped content for: https://bangla.bdnews24.com/business/eg80m38r0f
# Article 92: Successfully scraped content for: https://bangla.bdnews24.com/business/ubydp88tia
# Article 93: Successfully scraped content for: https://bangla.bdnews24.com/business/eg0r8lljmo
# Article 94: Successfully scraped content for: https://bangla.bdnews24.com/business/cqk6yddekb
# Article 95: Successfully scraped content for: https://bangla.bdnews24.com/business/hingzcitpr
# Article 96: Successfully scraped content for: https://bangla.bdnews24.com/business/hcl50wx0l1
# Article 97: Successfully scraped content for: https://bangla.bdnews24.com/business/45aj6q5k7i
# Article 98: Successfully scraped content for: https://bangla.bdnews24.com/business/yf7kuqhsmd
# Article 99: Successfully scraped content for: https://bangla.bdnews24.com/business/b8xh1c3fwx
# Article 100: Successfully scraped content for: https://bangla.bdnews24.com/business/64s042mnr4
# Article 101: Successfully scraped content for: https://bangla.bdnews24.com/business/lh65jgt4ub
# Article 102: Successfully scraped content for: https://bangla.bdnews24.com/business/wmaqqi9pb4
# Article 103: Successfully scraped content for: https://bangla.bdnews24.com/business/p3faiklcne
# Article 104: Successfully scraped content for: https://bangla.bdnews24.com/business/8tm6bpvrvc
# Article 105: Successfully scraped content for: https://bangla.bdnews24.com/economy/iex6n6lcmz
# Article 106: Successfully scraped content for: https://bangla.bdnews24.com/business/rnita7v8ak
# Article 107: Successfully scraped content for: https://bangla.bdnews24.com/business/qgvtqcwnkz
# Article 108: Successfully scraped content for: https://bangla.bdnews24.com/business/hrhnxxoald
# Article 109: Successfully scraped content for: https://bangla.bdnews24.com/business/k5nqzd85fq
# Article 110: Successfully scraped content for: https://bangla.bdnews24.com/business/f7k36tw82z
# Error fetching or decoding data: 429 Client Error: Too Many Requests for url: https://bangla.bdnews24.com/api/v1/collections/105128?item-type=story&offset=480&limit=10
